# %%
import pickle
import pandas as pd

# %%
saved_data = pd.DataFrame({'object': [None], 'category': [None], 'file_path': [None]})

with open('../save_files/saved_data.pkl', 'wb') as file:
    pickle.dump(saved_data, file)

# %%
# %run ../scripts/save_utils.py

# %%
with open('../save_files/saved_data.pkl', 'rb') as file:
        saved_data = pickle.load(file)
print(saved_data)
# Out:
#   object category file_path
# 0   None     None      None

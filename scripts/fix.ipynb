# %%
import os

model_path = '../save_files/models/baseline.h5'
print(os.listdir(model_path))
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[1], line 4
#       1 import os
#       3 model_path = '../save_files/models/baseline.h5'
# ----> 4 print(os.listdir(model_path))
#
# NotADirectoryError: [WinError 267] The directory name is invalid: '../save_files/models/baseline.h5'

# %%
import tensorflow as tf

tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\natur\Desktop\Machine Learning\Tumor_Detection_MRI\scripts
